# %%
import numpy as np
import trimesh

# %%
pts = np.load('vertices/0.npy', allow_pickle=True)

# %%
import matplotlib.pyplot as plt
plt.scatter(pts[:,0], pts[:,1])

# %%
mesh = trimesh.load_mesh('meshes/0.obj')

# %%
vertices = mesh.vertices

# %%
plt.plot(vertices[:,0], vertices[:,1], 'r.')

# %%
point_cloud = np.load('points/0.npy', allow_pickle=True)

# %%
plt.scatter(point_cloud[:,0], point_cloud[:,1], c='g')
print(len(point_cloud))
# Out:
# 94
